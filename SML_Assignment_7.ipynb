# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52074/Statical-Machine-Learning/blob/main/SML_Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
url = "/content/Salary_Data.csv"
data = pd.read_csv(url)
print(data.head())
X = data[['YearsExperience']]
y = data['Salary']
plt.scatter(X, y, color='red', label='Data Points')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Years of Experience vs Salary')
plt.legend()
plt.show()
model = LinearRegression()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
print(data.head())
X = data[['YearsExperience']]
y = data['Salary']
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='pink', label='Data Points', alpha=0.7)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Years of Experience vs Salary')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X)
plt.scatter(X, y, color='red', label='Data Points')
plt.plot(X, y_pred, color='black', linewidth=2, label='Best Fit Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Best Fit Line Using Linear Regression')
plt.legend()
plt.show()
print(f"Intercept: {model.intercept_}")
print(f"Coefficient: {model.coef_[0]}")
# Out:
# Intercept: 26780.09915062818
# Coefficient: 9312.575126729189

# %%
def evaluate_model(test_size):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0)
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    return mse, mae
for test_size in [0.2, 0.25]:
    mse, mae = evaluate_model(test_size)
    print(f"Test Size: {test_size * 100}%")
    print(f"Mean Squared Error (MSE): {mse}")
    print(f"Mean Absolute Error (MAE): {mae}\n")
# Out:
# Test Size: 20.0%
# Mean Squared Error (MSE): 12823412.298126549
# Mean Absolute Error (MAE): 2446.1723690465055
#
# Test Size: 25.0%
# Mean Squared Error (MSE): 22407940.143340684
# Mean Absolute Error (MAE): 3508.5455930660555

# %% [markdown]
# 2

# %%
import pandas as pd
data = {
    'Feature 1': [1.2, 2.4, 3.5, 4.1, 1.9, 3.7, 2.1, 3.3, 2.8, 4.0],
    'Feature 2': [2.3, 1.9, 2.7, 3.0, 2.8, 2.5, 3.2, 2.4, 3.1, 3.6],
    'Feature 3': [3.1, 2.8, 1.5, 4.1, 3.5, 4.1, 2.2, 3.3, 3.6, 2.7],
    'Feature 4': [4.2, 3.5, 2.9, 4.8, 4.0, 3.6, 4.1, 4.5, 1.8, 4.9],
    'Target': [15.6, 13.1, 12.4, 18.2, 14.1, 16.0, 14.5, 17.3, 14.9, 19.2]
}

df = pd.DataFrame(data)
data
# Out:
# {'Feature 1': [1.2, 2.4, 3.5, 4.1, 1.9, 3.7, 2.1, 3.3, 2.8, 4.0],
#  'Feature 2': [2.3, 1.9, 2.7, 3.0, 2.8, 2.5, 3.2, 2.4, 3.1, 3.6],
#  'Feature 3': [3.1, 2.8, 1.5, 4.1, 3.5, 4.1, 2.2, 3.3, 3.6, 2.7],
#  'Feature 4': [4.2, 3.5, 2.9, 4.8, 4.0, 3.6, 4.1, 4.5, 1.8, 4.9],
#  'Target': [15.6, 13.1, 12.4, 18.2, 14.1, 16.0, 14.5, 17.3, 14.9, 19.2]}

# %%
import matplotlib.pyplot as plt
features = ['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4']
plt.figure(figsize=(15, 10))
for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)
    plt.scatter(df[feature], df['Target'], color='green')
    plt.title(f'{feature} vs Target')
    plt.xlabel(feature)
    plt.ylabel('Target')
plt.tight_layout()
plt.show()

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='green', label='Predicted vs Actual')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='orange', linestyle='--', label='Best Fit Line')
plt.xlabel('Actual Target')
plt.ylabel('Predicted Target')
plt.title('Best Fit Line vs Actual Target')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
X = df[['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4']]
y = df['Target']
test_sizes = [0.2, 0.3]
for test_size in test_sizes:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    print(f'Test Size: {test_size}')
    print(f'Mean Squared Error: {mse:.2f}')
    print(f'Mean Absolute Error: {mae:.2f}')
    print('-' * 30)
# Out:
# Test Size: 0.2
# Mean Squared Error: 20.14
# Mean Absolute Error: 3.67
# ------------------------------
# Test Size: 0.3
# Mean Squared Error: 30.98
# Mean Absolute Error: 4.14
# ------------------------------
